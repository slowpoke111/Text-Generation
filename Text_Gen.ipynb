# %%
# %%capture
#default modules
import random

#Packages
import numpy as np
import pandas as pd
from nltk.tokenize import RegexpTokenizer

from google.colab import drive

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Activation
from tensorflow.keras.optimizers import RMSprop

# %%
#Load text into Pandas DataFrame
#https://huggingface.co/datasets/cmalaviya/expertqa

"""
Malaviya, Chaitanya, et al. "ExpertQA: Expert-Curated Questions and Attributed Answers." arXiv, September 2023. URL: https://arxiv.org/abs/2309.07852.
"""

text_df: pd.DataFrame =pd.read_json("/content/Science Fair/data1.json",lines=True)

text_df.head()

#Remove unneccesary columns
text_df.drop(labels=["example_id","context"],axis=1,inplace=True)

text_df.head()
# Out:
#                                             question  \
# 0  Some customers of mine are not paying their de...
# 1  When accounts are faced with ethical dilemmas ...
# 2  Looking at the South African tax law, what sho...
# 3  What would be the pros and cons of outsourcing...
# 4  A startup team has very experienced Ivy-league...
#
#                                               answer
# 0  You don't necessarily have to keep all your cu...
# 1  <Answer>  The context provided does not give s...
# 2  To enable South Africans to pay lower taxes un...
# 3  Outsourcing business operations involves deleg...
# 4  A venture capitalist should consider investing...

# %%
#Convert to List of words
questions=list(text_df["question"])
#Add to string
joined_questions=" ".join(questions)

#Tokenize
tokenizer=RegexpTokenizer(r"\w+")
tokens=tokenizer.tokenize(joined_questions.lower())
